# %%
# %matplotlib inline

# %%
from __future__ import print_function

import math
import numpy as np
import matplotlib.pyplot as plt

from skimage import data
from skimage.io import imread, imsave
from skimage import transform as tf
margins = dict(hspace=0.01, wspace=0.01, top=1, bottom=0, left=0, right=1)

# %%
shop = imread('theFieldHouse_bw.jpg', as_grey=True)

# %%
shop.shape
# Out:
# (375, 500)

# %%
text.shape
# Out:
# (172, 448)

# %%
warped.shape
# Out:
# (50, 300)

# %%
browserDim = (507,453)

# %%
dst[0]*browserDim
# Out:
# array([    0, 68445])

# %%
# text = data.text()

# src = np.array([[0, 0], [0, 50], [300, 50], [300, 0]])
# dst = np.array([[155, 15], [65, 40], [260, 130], [360, 95]])

text = shop

src = np.array([[0, 0], [0, 375], [373, 375], [373, 0]])
dst = np.array([[0, 52], [0, 313], [373, 371], [373, 0]])
browserDim = (507,453)

tform3 = tf.ProjectiveTransform()
tform3.estimate(src, dst)
#warped = tf.warp(text, tform3, output_shape=(50, 300))
warped = tf.warp(text, tform3, output_shape=shop.shape)

fig, ax = plt.subplots(nrows=2, figsize=(8, 3))

ax[0].imshow(text, cmap=plt.cm.gray)
ax[0].plot(dst[:, 0], dst[:, 1], '.r')
ax[1].imshow(warped, cmap=plt.cm.gray)

for a in ax:
    a.axis('off')

plt.tight_layout()

imsave('theFieldHouse_bw_warped.jpg',warped)
# Out:
# /home/pboord/anaconda2/lib/python2.7/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))

# %%
from PIL import Image
import sys
import pyocr
import pyocr.builders
tools = pyocr.get_available_tools()
if len(tools) == 0:
    print("No OCR tool found")
    sys.exit(1)
tool = tools[0]
txt = tool.image_to_string(
    Image.open('theFieldHouse_bw_warped_sign.jpg'),
    lang="eng",
    builder=pyocr.builders.TextBuilder()
)
txt
# Out:
# u'Waitrose'
